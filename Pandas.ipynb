# %%
pip install pandas
# Out:
# Collecting pandas
#   Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Requirement already satisfied: numpy>=1.26.0 in C:\Users\benha\anaconda3\envs\myenv311\Lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\benha\anaconda3\envs\myenv311\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\benha\anaconda3\envs\myenv311\Lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in C:\Users\benha\anaconda3\envs\myenv311\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp311-cp311-win_amd64.whl (9.9 MB)
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.9 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.9 MB 1.3 MB/s eta 0:00:08
#    --- ------------------------------------ 0.8/9.9 MB 1.3 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.9 MB 1.2 MB/s eta 0:00:08
#    ---- ----------------------------------- 1.0/9.9 MB 1.2 MB/s eta 0:00:08
#    ----- ---------------------------------- 1.3/9.9 MB 972.7 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.9 MB 932.2 kB/s eta 0:00:09
#    ------ --------------------------------- 1.6/9.9 MB 932.2 kB/s eta 0:00:09
#    ------- -------------------------------- 1.8/9.9 MB 958.5 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 970.4 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 970.4 kB/s eta 0:00:09
#    -------- ------------------------------- 2.1/9.9 MB 970.4 kB/s eta 0:00:09
#    --------- ------------------------------ 2.4/9.9 MB 798.9 kB/s eta 0:00:10
#    ---------- ----------------------------- 2.6/9.9 MB 843.5 kB/s eta 0:00:09
#    ------------ --------------------------- 3.1/9.9 MB 941.4 kB/s eta 0:00:08
#    --------------- ------------------------ 3.9/9.9 MB 1.1 MB/s eta 0:00:06
#    ------------------ --------------------- 4.5/9.9 MB 1.2 MB/s eta 0:00:05
#    --------------------- ------------------ 5.2/9.9 MB 1.3 MB/s eta 0:00:04
#    ----------------------- ---------------- 5.8/9.9 MB 1.4 MB/s eta 0:00:03
#    -------------------------- ------------- 6.6/9.9 MB 1.5 MB/s eta 0:00:03
#    ----------------------------- ---------- 7.3/9.9 MB 1.6 MB/s eta 0:00:02
#    ------------------------------- -------- 7.9/9.9 MB 1.7 MB/s eta 0:00:02
#    -------------------------------- ------- 8.1/9.9 MB 1.7 MB/s eta 0:00:02
#    ---------------------------------- ----- 8.7/9.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------ --- 8.9/9.9 MB 1.7 MB/s eta 0:00:01
#    ------------------------------------- -- 9.2/9.9 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.7 MB/s eta 0:00:01
#    -------------------------------------- - 9.4/9.9 MB 1.7 MB/s eta 0:00:01
#    ---------------------------------------  9.7/9.9 MB 1.6 MB/s eta 0:00:01
#    ---------------------------------------- 9.9/9.9 MB 1.5 MB/s  0:00:06
# Installing collected packages: pandas
# Successfully installed pandas-3.0.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
d = {"Name ": ["Alice","Bob"],"Age":[25,30]}
d
pd.DataFrame(d)
df = pd.read_csv("automobile_prices.csv")
df.head()
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 206 entries, 0 to 205
# Data columns (total 26 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   symboling          206 non-null    int64
#  1   normalized-losses  164 non-null    float64
#  2   make               206 non-null    str
#  3   fuel-type          206 non-null    str
#  4   aspiration         206 non-null    str
#  5   num-of-doors       204 non-null    str
#  6   body-style         206 non-null    str
#  7   drive-wheels       206 non-null    str
#  8   engine-location    206 non-null    str
#  9   wheel-base         206 non-null    float64
#  10  length             206 non-null    float64
#  11  width              206 non-null    float64
#  12  height             206 non-null    float64
#  13  curb-weight        206 non-null    int64
#  14  engine-type        206 non-null    str
#  15  num-of-cylinders   206 non-null    str
#  16  engine-size        206 non-null    int64
#  17  fuel-system        206 non-null    str
#  18  bore               202 non-null    float64
#  19  stroke             202 non-null    float64
#  20  compression-ratio  206 non-null    float64
#  21  horsepower         204 non-null    float64
#  22  peak-rpm           204 non-null    float64
#  23  city-mpg           206 non-null    int64
#  24  highway-mpg        206 non-null    int64
#  25  price              206 non-null    int64
# dtypes: float64(10), int64(6), str(10)
# memory usage: 42.0 KB

# %%
df2 = pd.read_csv("houses_to_rent_to_fix.csv")
df2.head()
print(f"There are {df2.isnull().sum()}")
df2[df2["bathroom"]<5]
pivot = df2.pivot_table(
    index = "rooms",
    aggfunc = "count",
    values = "city"
)
pivot.plot(kind="bar")
# Out:
# There are city                   0
# area                   0
# rooms                  4
# bathroom               0
# parking spaces         0
# floor                  0
# animal                 0
# furniture              0
# hoa (R$)               0
# rent amount (R$)       0
# property tax (R$)      0
# fire insurance (R$)    0
# total (R$)             0
# dtype: int64
# <Axes: xlabel='rooms'>

# %%
df2["total (R$)"].max()
# Out:
# np.int64(1120000)
