# %%
my_list = []
for i in range(10):
    my_list.append(i*10)

    
for x in my_list[:]:
    if x == 20:
        my_list.remove(x)

print(my_list[:-3])

my_tuple = ("apple","bannana","cherry")

print(my_tuple.count("apple"))

students = [
    {"id": 1, "name": "Ali", "age": 20, "grade": "A"},
    {"id": 2, "name": "Sara", "age": 21, "grade": "B"},
    {"id": 3, "name": "Omar", "age": 22, "grade": "A"},
    {"id": 4, "name": "Lina", "age": 19, "grade": "C"},
    {"id": 5, "name": "Adam", "age": 23, "grade": "B"},
    {"id": 6, "name": "Maya", "age": 20, "grade": "A"},
    {"id": 7, "name": "Youssef", "age": 24, "grade": "B"},
    {"id": 8, "name": "Nour", "age": 21, "grade": "A"},
    {"id": 9, "name": "Karim", "age": 22, "grade": "C"},
    {"id": 10, "name": "Hana", "age": 20, "grade": "B"}
]


def student_fail(l):
    x=0
    for i in l:
        if i["grade"]== "C":
            x += 1
    return x
student_fail(students)
# Out:
# [0, 10, 30, 40, 50, 60]
# 1
# Found Germany!

# %%
schengen_countries = [
    "France", "Germany", "Spain", "Netherlands", "Belgium",
    "Austria", "Portugal", "Switzerland", "Sweden", "Norway",
    "Denmark", "Finland", "Poland", "Czech Republic", "Greece",
    "Hungary", "Slovakia", "Slovenia", "Croatia", "Estonia",
    "Latvia", "Lithuania", "Iceland", "Luxembourg", "Malta",
    "Liechtenstein"
]

i = 0

while i < len(schengen_countries):
    if schengen_countries[i] == "Germany":
        print("Found Germany!")
        break
    i += 1
# Out:
# Found Germany!
