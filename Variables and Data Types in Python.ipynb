# %%
int maxDistance
float Temperature
str greet_ing

bool isRainging

1st_value   → first_value
Total$Amount → total_amount
CalcNum     → calc_num
Data-Entry  → data_entry


num_float = float(42)
print(num_float)


num_int = int(3.14159)
print(num_int)


num_str = str(99.99)
print(num_str)

num_float_again = float(num_str)
print(num_float_again)
