# %%
#Ex1
s1 = 'String one'
s2 = "String two"
s3 = """multiple 
line 
string """

#Ex2
print('%s1' % s1)
print(f"{s2}")
print("All strings {} {} {}".format(s1,s2,s3))

# Ex3
def first_last_two(s):
    if len(s) > 2:
        return s[:2] + s[-2:]
    else:
        return "String is too short"


# Ex4
def transform(s):
    if len(s) > 2:
        return s[:2].upper() + s[-2:].upper()
    else:
        return "String is too short"
# Out:
# String one1
# String two
# All strings String one String two multiple
# line
# string
